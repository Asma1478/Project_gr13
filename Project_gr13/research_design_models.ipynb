# %% [markdown]
# ## LDA topic modeling
#
# Question:
#  > How did sustainability language shift from Brundtland keywords toward sector-specific keywords after 2015?
#
# We perform LDA to obtain: <br>
#  > Topic distributions per document <br>
#  > Keyword representation of topics <br>
#  > Topic prevalence across subsets <br>
#
# Our steps:
#
#  > 1. Discover latent topics; for this we run LDA on all documents
#  > 2. Interpret the topics and label them
#  > 3. Compare prevalences of topics; for this we compute the average topic proportion by period (pre vs post) and sector-group

# %%
# pip install polars
# pip install pyarrow
# pip install scikit-learn

# %%
import polars as pl
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# load df_en
df_en = pl.read_csv("df_en.csv")

# %%
# extract the text from the clean text column as list for vectorization
texts = df_en["text_clean"].to_list()

# %%
# see documentation for details: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html



vectorizer = CountVectorizer(
    max_df=0.9,
    min_df=10,
    stop_words="english"
)

dtm = vectorizer.fit_transform(texts)

# %%
# Here we run the LDA, which is a ready-to-use thing in sklearn > we need to decide for n_components, the number of topics we specify

lda = LatentDirichletAllocation(
    n_components=12,
    random_state=42 # reproducibility 
)

doc_topics = lda.fit_transform(dtm)

# %%
# run it another time with n_components = 6 

lda = LatentDirichletAllocation(
    n_components=6,
    random_state=42 # reproducibility 
)

doc_topics = lda.fit_transform(dtm)

# %% [markdown]
# we merge the topics (their proportions per document) with the reports in df_en:

# %%
topic_cols = [f"topic_{i}" for i in range(doc_topics.shape[1])]

topic_df = pl.DataFrame(doc_topics, schema=topic_cols)

df_en = df_en.with_columns(topic_df)

# %%
df_en
# Out:
# shape: (1_653, 26)
# ┌──────────────┬──────────────┬──────┬─────────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ filename     ┆ company_name ┆ year ┆ Name        ┆ … ┆ topic_2  ┆ topic_3  ┆ topic_4  ┆ topic_5  │
# │ ---          ┆ ---          ┆ ---  ┆ ---         ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str          ┆ str          ┆ i64  ┆ str         ┆   ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════════╪══════════════╪══════╪═════════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ Anasoft_2015 ┆ Anasoft      ┆ 2015 ┆ Anasoft     ┆ … ┆ 0.555149 ┆ 0.000055 ┆ 0.034082 ┆ 0.005538 │
# │ .txt         ┆              ┆      ┆             ┆   ┆          ┆          ┆          ┆          │
# │ AECOM_2016.t ┆ AECOM        ┆ 2016 ┆ AECOM       ┆ … ┆ 0.934657 ┆ 0.000052 ┆ 0.000052 ┆ 0.049313 │
# │ xt           ┆              ┆      ┆             ┆   ┆          ┆          ┆          ┆          │
# │ KimballOffic ┆ KimballOffic ┆ 2016 ┆ Kimball     ┆ … ┆ 0.961157 ┆ 0.00015  ┆ 0.03824  ┆ 0.000151 │
# │ e_2016.txt   ┆ e            ┆      ┆ Office      ┆   ┆          ┆          ┆          ┆          │
# │ CascadeEngin ┆ CascadeEngin ┆ 2016 ┆ Cascade     ┆ … ┆ 0.75818  ┆ 0.000061 ┆ 0.000061 ┆ 0.241577 │
# │ eering_2016. ┆ eering       ┆      ┆ Engineering ┆   ┆          ┆          ┆          ┆          │
# │ txt          ┆              ┆      ┆             ┆   ┆          ┆          ┆          ┆          │
# │ VodafoneQata ┆ VodafoneQata ┆ 2013 ┆ Vodafone    ┆ … ┆ 0.641667 ┆ 0.00191  ┆ 0.047739 ┆ 0.00015  │
# │ r_2013.txt   ┆ r            ┆      ┆ Qatar       ┆   ┆          ┆          ┆          ┆          │
# │ …            ┆ …            ┆ …    ┆ …           ┆ … ┆ …        ┆ …        ┆ …        ┆ …        │
# │ ADFIAP_2009. ┆ ADFIAP       ┆ 2009 ┆ ADFIAP      ┆ … ┆ 0.439858 ┆ 0.316892 ┆ 0.038542 ┆ 0.001026 │
# │ txt          ┆              ┆      ┆             ┆   ┆          ┆          ┆          ┆          │
# │ SCJohnson_20 ┆ SCJohnson    ┆ 2014 ┆ SC Johnson  ┆ … ┆ 0.903767 ┆ 0.000028 ┆ 0.000028 ┆ 0.066081 │
# │ 14.txt       ┆              ┆      ┆             ┆   ┆          ┆          ┆          ┆          │
# │ OrientOverse ┆ OrientOverse ┆ 2016 ┆ Orient      ┆ … ┆ 0.459045 ┆ 0.000013 ┆ 0.078742 ┆ 0.082728 │
# │ asInternatio ┆ asInternatio ┆      ┆ Overseas    ┆   ┆          ┆          ┆          ┆          │
# │ nal_20…      ┆ nal          ┆      ┆ Internation ┆   ┆          ┆          ┆          ┆          │
# │              ┆              ┆      ┆ al          ┆   ┆          ┆          ┆          ┆          │
# │ AhlstromCorp ┆ AhlstromCorp ┆ 2011 ┆ Ahlstrom    ┆ … ┆ 0.78986  ┆ 0.00004  ┆ 0.00004  ┆ 0.167314 │
# │ oration_2011 ┆ oration      ┆      ┆ Corporation ┆   ┆          ┆          ┆          ┆          │
# │ .txt         ┆              ┆      ┆             ┆   ┆          ┆          ┆          ┆          │
# │ SakariResour ┆ SakariResour ┆ 2013 ┆ Sakari      ┆ … ┆ 0.391092 ┆ 0.026022 ┆ 0.002967 ┆ 0.000109 │
# │ ces_2013.txt ┆ ces          ┆      ┆ Resources   ┆   ┆          ┆          ┆          ┆          │
# └──────────────┴──────────────┴──────┴─────────────┴───┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# we print out the 50 most frequent words for each topic:

# %%
def get_top_words_transposed(model, feature_names, n_top_words=50):
    topic_dict = {}

    for topic_idx, topic in enumerate(model.components_):
        top_features = topic.argsort()[:-n_top_words - 1:-1]
        words = [feature_names[i] for i in top_features]

        # each topic becomes a column
        topic_dict[f"topic_{topic_idx}"] = words

    # Polars automatically aligns lists as rows
    df = pl.DataFrame(topic_dict)

    # optional: add rank index
    df = df.with_row_index("rank", offset=1)

    # move rank to first column
    df = df.select(["rank"] + [c for c in df.columns if c != "rank"])

    return df


feature_names = vectorizer.get_feature_names_out()
df_topics = get_top_words_transposed(lda, feature_names)

df_topics
# Out:
# shape: (50, 7)
# ┌──────┬────────────────┬────────────────┬────────────────┬─────────────┬─────────────┬───────────┐
# │ rank ┆ topic_0        ┆ topic_1        ┆ topic_2        ┆ topic_3     ┆ topic_4     ┆ topic_5   │
# │ ---  ┆ ---            ┆ ---            ┆ ---            ┆ ---         ┆ ---         ┆ ---       │
# │ u32  ┆ str            ┆ str            ┆ str            ┆ str         ┆ str         ┆ str       │
# ╞══════╪════════════════╪════════════════╪════════════════╪═════════════╪═════════════╪═══════════╡
# │ 1    ┆ group          ┆ sustainability ┆ sustainability ┆ financial   ┆ group       ┆ power     │
# │ 2    ┆ gas            ┆ safety         ┆ emissions      ┆ group       ┆ csr         ┆ group     │
# │ 3    ┆ safety         ┆ product        ┆ safety         ┆ board       ┆ japan       ┆ fiscal    │
# │ 4    ┆ sustainability ┆ india          ┆ program        ┆ assets      ┆ fy          ┆ electric  │
# │ 5    ┆ project        ┆ organization   ┆ waste          ┆ million     ┆ fiscal      ┆ sales     │
# │ …    ┆ …              ┆ …              ┆ …              ┆ …           ┆ …           ┆ …         │
# │ 46   ┆ principles     ┆ production     ┆ supply         ┆ related     ┆ basic       ┆ cost      │
# │ 47   ┆ compliance     ┆ power          ┆ climate        ┆ asset       ┆ internal    ┆ plants    │
# │ 48   ┆ policy         ┆ regulations    ┆ paper          ┆ march       ┆ promoting   ┆ customers │
# │ 49   ┆ mobile         ┆ emissions      ┆ strategy       ┆ meeting     ┆ hitachi     ┆ iino      │
# │ 50   ┆ human          ┆ directors      ┆ diversity      ┆ investments ┆ procurement ┆ demand    │
# └──────┴────────────────┴────────────────┴────────────────┴─────────────┴─────────────┴───────────┘

# %%
df_topics.write_csv("topics_6.csv")

# %% [markdown]
# above we see that some words we could consider removing form the text, like names of companies and countries

# %% [markdown]
# to get a better idea about the topics and ensure proper labeling, we can find those reports with the highest probability for each topic:

# %%
texts = df_en["text_clean"].to_list()
files = df_en["filename"].to_list()

import numpy as np

for k in range(doc_topics.shape[1]):
    top_docs = np.argsort(doc_topics[:, k])[-5:]   # top 5 docs

    print(f"\n===== Topic {k} =====")

    for d in reversed(top_docs):   # highest first
        print(f"\nFILE: {files[int(d)]}")
        print(texts[int(d)][:400])
# Out:
# ===== Topic 0 =====
#
# FILE: TeollisuudenVoimaOyj(TVO)_2014.txt
# corporate social responsibility report table of contents responsible leadership review by the ceo operating environment strategic objectives good corporate governance risk management management system company level policies code of conduct safety safety culture development special events research and development uranium from bedrock to bedrock procurement of uranium nuclear power plant olkiluoto a
#
# FILE: TeollisuudenVoimaOyj(TVO)_2016.txt
# well being with nuclear electricity corporate social responsibility report table of contents responsible leadership review by the ceo operating environment strategic goals responsibility program risk management management system business ethics communal influencer tvo an overview creation of jobs and benefits to national economy well being and employment economic impacts significant climate and en
#
# FILE: TeollisuudenVoimaOyj(TVO)_2015.txt
# corporate social responsibility report table of contents responsible leadership review by the ceo operating environment strategic objectives responsibility program good corporate governance risk management management system company level policies code of conduct safety safety culture development special events research and development uranium from bedrock to bedrock procurement of uranium nuclear
#
# FILE: VodafoneGreece_2010.txt
# contents letter from the chairman of the board of directors and chief executive introductory note about vodafone greece and the vodafone group managing corporate responsibility environment mobile phones masts health network deployment customers access to communications supply chain employees social investment objectives results new commitments table main figures in table form website index abbrevi
#
# FILE: SiamCommercialBank_2014.txt
# think of giving sustainability report o jg wuvckpcdknkv grqtv ku rctv qh c ugv vjcv kpenwfgu vjg ppwcn grqtv jcv ku vjkpmkpi hvgt c hgy gctu qh dwq cpv etgfkv itqyvj vjg jck geqpqo fgxcuvcvkpi ɲqqfu qtgqxgt vjg nqpi cyckvgf kphtcuvtwevwtg vqqm c e enkecn vwtp hqt vjg yqtug htqo okf qpyctf u urgpfkpi ycu fghgttgf fwg vq ejcnngpigu vq vjg ngicnkv qh vjg fqoguvke eqpuworvkqp hwgnnkpi geqpqoke itqyvj
#
# ===== Topic 1 =====
#
# FILE: BajajAuto_2015.txt
# business responsibility report section a general information about the company corporate identification number l pn plc name of the company bajaj auto ltd registered address mumbai pune road akurdi pune website www bajajauto com email address brr response bajajauto co in financial year reported april march sector s that the company is engagement in automobile key products services manufactured mot
#
# FILE: BajajAuto_2016.txt
# business responsibility report section a general information about the company corporate identification number l pn plc name of the company bajaj auto ltd registered address mumbai pune road akurdi pune website www bajajauto com email address brr response bajajauto co in financial year reported april march sector s that the company is engaged in automobile three key products services manufactured
#
# FILE: Cigna_2015.txt
# gna connects ci bi corporateresponsi ty report li tableofcontents table of contents gna connects ci d m cordani message from davi dent and ceo of ci presi gna gna connects our uni ci bi que approach to corporate responsi ty li cr snapshot s report about thi ness busi our company governance cs i ethi ty ntegri vacy i pri on protecti nformati on n management supply chai people stakeholder engagement
#
# FILE: KoreaLandCorporation_2010.txt
# sustainability report promise for you contents promise land green land cover story promise for you promise land wonder land green land wonder land about the sustainability report a message from our ceo russia mongolia azerbaijan kyrgyzstan korea land corporation algeria senegal china libya yemen india cambodia vietnam ghana nigeria tanzania global land designer nation is land corporate is tree his
#
# FILE: SuperRetailGroup_2015.txt
# corporate re v iew inspir i ng you to li ve your passi reviewon super retail group limited corporate ta b l e o f c o n t e n t s highlights about us our story our journey our stores our governance our strategic roadmap from our ceo our strategic agenda our innovation supply chain customer loyalty programs digital our people our team our values learning and organisational development communication
#
# ===== Topic 2 =====
#
# FILE: TetraPakInternational_2017.txt
# people futures sustainabilitybility report food people futures our food people futures approach ceo reflections delivering on our promise our president and ceo dennis jönsson looks back on another year in which we brought sustainable value to stakeholders by delivering on our simple unifying promise understanding our role in the world distribution systems for milk and other during the past year we
#
# FILE: PitneyBowes_2010.txt
# corporate responsibility report our commitment to innovation and at pitney bowes citizenship spans corporate responsibility is every aspect of our everyone s responsibility business it drives our success and defines us as a company our business practices environment diversity our people customers and suppliers community every connection is a new opportunity our business practices our values provid
#
# FILE: BrookdaleSeniorLiving_2016.txt
# creating enduring value sustainability report about this report we are pleased to provide our first sustainability report it shares the early stages of the sustainability journey we are undertaking outlining where we are now and where we are heading our commitment to sustainability is rooted in our sustainability mission of enriching the lives of those we serve by creating enduring value with our
#
# FILE: RobertHalfInternational_2015.txt
# investing corporate citizenship report in people at robert half our mission is to help businesses grow by matching the right talent to their specialized staffing and consulting needs and build rewarding careers for the professionals we place adhere to a philosophy of ethics first in everything we do create a work environment where employees can thrive and innovate be a socially responsible corpora
#
# FILE: BrookfieldOfficeManagement_2017.txt
# table of contents message from the cso governance tenant engagement tenant survey mybrookfield communications platform global best practices committees environmental measuring achievement global real estate sustainability benchmark green building certifications case studies usgbc north american leed volume waste and solar projects tenant sustainability events saving energy at figueroa los angeles
#
# ===== Topic 3 =====
#
# FILE: SampoGroup_2016.txt
# table of contents group governance board of directors report risk management financial statements calendar and contacts annual report annual report group group group gr re oup ceo s r view eview figures in figur es tra strategy if p c insurance mandatum life group gr structur oup s e tructure organiza or tion ganization businesses busines ses if p c insurance nordea mandatum life personnel if p c
#
# FILE: SampoGroup_2015.txt
# table of contents group governance board of directors report risk management financial statements calendar and contacts annual annual report annual annual report group gr oup group group ceo s review in figures strategy if p c insurance mandatum life group structure organization businesses if p c insurance nordea mandatum life personnel if p c insurance mandatum life corporate responsibility if p
#
# FILE: SampoGroup_2014.txt
# sampo sampo group s annual report table of contents table of contents group governance board of directors report risk management financial statements calendar and contacts sampo group s annual report group group group ceo s review in figures strategy group structure organization businesses if p c insurance nordea mandatum life personnel if p c insurance mandatum life corporate responsibility if p
#
# FILE: Oriola-KD_2017.txt
# health wellbeing oriola kd annual report oriola kd business environment strategy business areas cases corporate governance financial statements contents oriola kd in brief services mission and vision healthcare ceo s review oriola kd as an investment industry sector and markets responsibility strategy and targets cases medicine s path board of directors business areas group management team consume
#
# FILE: ImbalieBeauty_2013.txt
# contents page overview board of directors report of chairman and chief executive officer corporate governance annual financial statements independent auditors report directors responsibilities and approval certification by company secretary audit committee report directors report statement of financial position statement of comprehensive income statement of changes in equity statement of cash flow
#
# ===== Topic 4 =====
#
# FILE: SumitomoForestry_2013.txt
# vision for the sustainable development sumitomo forestry group csr report csr report contents top message environmental report environmental management management system environmental philosophy and environmental policies corporate governance environmental management structure risk management and compliance environmental education and training csr management environmental risk management promoting
#
# FILE: Lawson_2011.txt
# corporate citizenship report happiness and harmony in our community 電 気自動車 contents contents contents corporate philosophy and editorial policy boosting reducing waste providing safe secure and healthy products corporate philosophy and editorial policy top commitment helping to build a recycling society ensuring customer safety and health top commitment value of the existence of the lawson group c
#
# FILE: Lawson_2012.txt
# corporate citizenship report creating happiness and harmony in our communities how to view this report jump directly to any section from contents click an entry on this table of contents to jump to that topic the menu on the left of each page editorial policy to create a resource recycling society with everyone top commitment reducing and recycling food keeping customers satisﬁed thrown away at st
#
# FILE: TorayIndustriesInc_2013.txt
# the entire site of social responsibility as of december contents csr top message from the president toray group s corporate social responsibility csr guidelines csr road map and kpi history of toray s csr activities external commendations for our customers green innovation businesses moving forward with the green innovation business expansion project promoting life cycle management approach to gre
#
# FILE: EastJapanRailway_2012.txt
# jr east group sustainability report aiming for a sustainable society jr east group sustainability report c o n t e n t s ed ito r ia l p o l icy editorial policy we publish the jr east group sustainability group philosophy basic principles report with the aim of introducing various top message initiatives by group companies accurately and special topic in an easy to understand format as well as ra
#
# ===== Topic 5 =====
#
# FILE: GPSC_2016.txt
# synergizing power utilities for the global future global power synergy public company limited gpsc strives to be the main power and utility of ptt group and devotes to sustain our growing path by enhancing trust of stakeholders adhering to the best business practices committing to good corporate governance challenging various business opportunities and being responsible for society and environment
#
# FILE: IinoLines_2011.txt
# iino report csr annual report v a l u e i n n o v a t o r s b o u n d f o r b r o a d h orizons the iino group s history dates all the way back to when forerunner iino shokai was established at maizuru port kyoto to transport coal by barge during its years in business the company has developed a thriving marine shipping business alongside which its real estate operations have developed into a seco
#
# FILE: IinoLines_2014.txt
# value innovators bound for broad horizons c s r a n n u a l r e p o r t iino report t h e y e a r e n d e d m a r c h iino group philosophy safety is the foundation of our business operations we will always provide a stable supply of good services and products at fair prices we will respond to customers needs promptly we will respect the law and uphold our social and environmental responsibilities
#
# FILE: IinoLines_2015.txt
# value innovators bound for broad horizons c s r a n n u a l r e p o r t iino report the year ended march iino group philosophy safety is the foundation of our business operations we will always provide a stable supply of good services and products at fair prices we will respond to customers needs promptly we will respect the law and uphold our social and environmental responsibilities we will cons
#
# FILE: IinoLines_2010.txt
# iino report csr annua l repor t value innovators b o u n d f o r b r o a d h o r i z o n s the iino group s history dates all the way back to when forerunner iino shokai was established at maizuru port kyoto to transport coal by barge during its years in business the company has developed a thriving marine shipping business alongside which its real estate operations have developed into a second co
